# %% [markdown]
# <a href="https://colab.research.google.com/github/varshasisodiya16-arch/first-repository/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n =(int(input ("enter a number: ")))
for i in range(1,11):
  print(n*i)
# Out:
# enter a number: 5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
x=100
y=100
print(x==y)
print (x is y)
# Out:
# True
# True

# %% [markdown]
# PYTHON DATASTRUCTURE
# list
# tuple
# dictionarry
# set

# %%
#list
list1=["varsha",21,"b tech","mathura",5.4]
print(list1)
# Out:
# ['varsha', 21, 'b tech', 'mathura', 5.4]

# %%
# length of list
print(len(list1))
# Out:
# 5

# %%
# fetch value
print(list1[3])
# Out:
# mathura

# %%
# append
list1.append("31")

# %%
# insert
list1.insert(1,"Sisodiya")

# %%
# update
list1[5]=5.5
print(list1)
# Out:
# ['varsha', 'Sisodiya', 21, 'b tech', 5.5, 5.5]

# %%
# extend
list2=[1,2,3,4]
list2.extend(list1)
print(list2)
# Out:
# [1, 2, 3, 4, 'varsha', 'Sisodiya', 'Sisodiya', 21, 'b tech', 5.5, 5.5]

# %%
# remove
list1.remove("Sisodiya")
print(list1)
# Out:
# ['varsha', 'Sisodiya', 21, 'b tech', 5.5, 5.5]

# %%
# pop
x=list2.pop(3) # index pass krni h
print(x)
# Out:
# varsha

# %%
# count occurance
print(list1.count("varsha"))
# Out:
# 1

# %%
#sorting
list2.sort
print(list2)
# Out:
# [1, 3, 4, 'Sisodiya', 'Sisodiya', 21, 'b tech', 5.5]

# %%
# clear the list
list1.clear()
print(list1)
# Out:
# []

# %%
 # tuple immitable
t1=(1,2,3,4)
print(t1)
# Out:
# (1, 2, 3, 4)

# %%
# change value by type casting
t1[2]="hello"

# %%
#SET
set1={1,2,3,"V",1,4,"h"}
set2={3,4,1,7,"v"}
print(set1)
print(set1.intersection(set2))
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 'h', 'V'}
# {1, 3, 4}
# {1, 2, 3, 4, 7, 'h', 'v', 'V'}
