# %% [markdown]
# <a href="https://colab.research.google.com/github/varshasisodiya16-arch/first-repository/blob/main/diabetes_data_analyses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head(4)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# to check missing value
df.isnull().count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#check the duplicate values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
df.duplicated().count()
# Out:
# np.int64(768)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# check the invalid zero values
(df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]==0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %% [markdown]
# selsecting the data and filter the *date*

# %%
#select a column
df['BloodPressure']
# Out:
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64

# %%
df[['Age','BloodPressure']]
#multiple column
# Out:
#      Age  BloodPressure
# 0     50             72
# 1     31             66
# 2     32             64
# 3     21             66
# 4     33             40
# ..   ...            ...
# 763   63             76
# 764   27             70
# 765   30             72
# 766   47             60
# 767   23             70
#
# [768 rows x 2 columns]

# %%
#filter rows by some conditions
df[df['Age']>60].count()
# Out:
# Pregnancies                 27
# Glucose                     27
# BloodPressure               27
# SkinThickness               27
# Insulin                     27
# BMI                         27
# DiabetesPedigreeFunction    27
# Age                         27
# Outcome                     27
# dtype: int64

# %%
#filter with multiple condition
df[(df['Age'] > 65) & (df['Outcome'] == 1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 221            2      158             90              0        0  31.6
# 363            4      146             78              0        0  38.5
# 666            4      145             82             18        0  32.5
# 759            6      190             92              0        0  35.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 221                     0.805   66        1
# 363                     0.520   67        1
# 666                     0.235   70        1
# 759                     0.278   66        1

# %%
#access rows by index
df.iloc[700:709]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 700            2      122             76             27      200  35.9
# 701            6      125             78             31        0  27.6
# 702            1      168             88             29        0  35.0
# 703            2      129              0              0        0  38.5
# 704            4      110             76             20      100  28.4
# 705            6       80             80             36        0  39.8
# 706           10      115              0              0        0   0.0
# 707            2      127             46             21      335  34.4
# 708            9      164             78              0        0  32.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 700                     0.483   26        0
# 701                     0.565   49        1
# 702                     0.905   52        1
# 703                     0.304   41        0
# ...

# %% [markdown]
# Sorting and grouping

# %%
#sort by using a column
df.sort_values(by='Age')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 736            0      126             86             27      120  27.4
# 738            2       99             60             17      160  36.6
# 721            1      114             66             36      200  38.1
# 60             2       84              0              0        0   0.0
# 290            0       78             88             29       40  36.9
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 736                     0.515   21        0
# ...

# %%
#Value count
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# Statistics
# mean of column
df['BMI'].mean()
# Out:
# np.float64(31.992578124999998)

# %%
#Median
df['Glucose'].median()
# Out:
# 117.0

# %% [markdown]
# Modification of data

# %%
# add a ner=w column
df['BloodPressure_CATEGORY']=pd.cut(df['BloodPressure'],bins[5, 5],labels=[h,S])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_920/3249481279.py in <cell line: 0>()
#       1 # add a ner=w column
# ----> 2 df['BloodPressure_CATEGORY']=pd.cut(df['BloodPressure'],bins[5, 5],labels=[h,S])
#
# NameError: name 'bins' is not defined

# %%
# replace invalid zeroes
df['Insulin']= df['Insulin'].replace(0,df['Insulin'].mean)

# %% [markdown]
# Data visualisation

# %% [markdown]
# # Hitogram
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.hist(df[Age])
# plt.xlabel('Age')
# plt.ylabel('Frequency)

# %%
#Histogram
import matplotlib.pyplot as plt
import seaborn as sns

plt.hist(df['Age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_917/70487474.py in <cell line: 0>()
#       3 import seaborn as sns
#       4
# ----> 5 plt.hist(df['Age'])
#       6 plt.xlabel('Age')
#       7 plt.ylabel('Frequency')
#
# NameError: name 'df' is not defined
